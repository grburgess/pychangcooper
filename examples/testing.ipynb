# %%
# Scientific libraries
import numpy as np

# %matplotlib notebook
import matplotlib.pyplot as plt
from jupyterthemes import jtplot
jtplot.style(context='notebook', fscale=1)
import seaborn as sns

#optional 3ML imports

from glob import glob
import copy
import collections
#import warnings
#warnings.simplefilter('ignore')

from pychangcooper import SynchrotronCooling, SynchrotronCoolingWithEscape

# %%
sc = SynchrotronCooling(n_grid_points=300,gamma_cool=300, gamma_max=1E4, store_progress=True)

# %%
sc.run()

# %%
fig, ax  = plt.subplots()

ax.loglog(sc.grid,sc.n,'.')



ax.loglog(sc.grid,sc._source_grid,'.')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
sc = SynchrotronCoolingWithEscape(n_grid_points=300,
                                     gamma_cool=300,
                                     gamma_max=1E4,
                                     t_esc=1E3,
                                     store_progress=True)
sc.run()
# Out:
# here
# ...

# %%
fig, ax  = plt.subplots()

ax.loglog(sc.grid,sc.n,'.')



ax.loglog(sc.grid,sc._source_grid,'.')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
fig, ax  = plt.subplots()

for spec in sc.history:


    ax.loglog(sc.grid,spec,'.')
# Out:
# <img src="data:image/png;base64,..." width="800">
# /Users/jburgess/.environs/science3/lib/python3.6/site-packages/matplotlib/ticker.py:2206: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   "Data has no positive values, and therefore cannot be "

# %%
class DummyChild(ChangCooper):

    def _define_terms(self):

        self._dispersion_term = np.ones(self._n_grid_points)

        self._heating_term = np.ones(self._n_grid_points)

# %%
dummy = DummyChild(n_grid_points=10)
# Out:
# /Users/jburgess/.environs/science/lib/python2.7/site-packages/pychangcooper-0.1-py2.7.egg/pychangcooper/chang_cooper.py:101: RuntimeWarning: overflow encountered in exp
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-a0222cb35089> in <module>()
# ----> 1 dummy = DummyChild(n_grid_points=10)
#
# /Users/jburgess/.environs/science/lib/python2.7/site-packages/pychangcooper-0.1-py2.7.egg/pychangcooper/chang_cooper.pyc in __init__(self, n_grid_points, max_grid, store_progress)
#      32
#      33         # now compute the tridiagonal terms
# ---> 34         self._setup_vectors()
#      35
#      36         # if there are no dispersion terms we do not need to forward sweep
#
# /Users/jburgess/.environs/science/lib/python2.7/site-packages/pychangcooper-0.1-py2.7.egg/pychangcooper/chang_cooper.pyc in _setup_vectors(self)
#     129
#     130             # n_j term
# ...

# %%
sc._delta_t
# Out:
# 773.7901790550476

# %%
sc._escape_grid
# Out:
# 0

# %%
sc._escape_function(10)
# Out:
# 0

# %%
plt.style.use('fivethirtyeight')
